# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import csv
import sys
#import network_distance as nd

# %%
backboned_n = "./data/0_Golden_Standard/countries_flights_norm_backbone_04.csv"

# %%
bckfl_df = pd.read_csv(backboned_n,sep=',')
bckfl_df
# Out:
#      Unnamed: 0                                                src  \
# 0             0                                             Bhutan
# 1             1                                        Afghanistan
# 2             2                                        Afghanistan
# 3             3                                         Seychelles
# 4             4                                            Albania
# ..          ...                                                ...
# 388         388                                          Sri Lanka
# 389         389                               United Arab Emirates
# 390         390  United Kingdom of Great Britain and Northern I...
# 391         391  United Kingdom of Great Britain and Northern I...
# 392         392                                              Yemen
#
#                             trg       nij     score  region  \
# 0                         India  0.175779  0.971264    Asia
# ...

# %%
bckfl_df = bckfl_df.sort_values(by=['weeks_since_100_cases'])

# %%
Data = open(backboned_n, "r")

next(Data2, None)  # skip the first line in the input file
Graphtype = nx.Graph()

G_w = nx.read_weighted_edgelist(Data2, delimiter=',', create_using=Graphtype, nodetype=str,)

# %%
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, './distance_measure/implementation')

# %%
# what nodes should be in source and target and with what intensity?

#0 is implicitly assumed in the library already. 
#create src dic with all countries = 0
#create trg dic with all countries = 0

#Where is the node intensity defined in this case? Greece=1 is not an edge weight, right?...

# SRC = TRG Intensity since the network is undirected?

# do it once, then create a function that can do this recursively. 
 
# PASS all the nodes that are infected (SI Model).
# ALL the countries that have the virus at that particular time. 

def build_src_trg(df, src_col, trg_col, covid_col)
    for index, row in df.iterrows():
    
    #print(row['c1'], row['c2'])
    

result = {1:[src_1, trg_1]}

src = {"Greece":1} #week i-1 infected.
trg = {"Serbia":1} #week i infected.

#week by week, the distance will decrease. Both should go down to a point that

# %%
ge_dist = nd.ge(src, trg, G_w)
ge_dist
